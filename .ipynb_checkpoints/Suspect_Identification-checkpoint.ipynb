# %%
import os
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from PIL import Image
import torch.nn.functional as F
import matplotlib.pyplot as plt
import torchreid
from torchreid.utils import FeatureExtractor

class reidDataset(Dataset):
    def __init__(self, file_list, transform=None):
        self.file_list = file_list
        self.transform = transform

    def __len__(self):
        return len(self.file_list)

    def __getitem__(self, idx):
        img_path = self.file_list[idx]
        img = Image.open(img_path).convert('RGB')
        if self.transform:
            img = self.transform(img)
        return img

extractor = FeatureExtractor(
    model_name='osnet_x1_0',
    device='cuda'
)

transform = transforms.Compose([
    transforms.Resize((256, 128)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])


img_dir = './reid_data/my_dataset/bounding_box_test'
candidates_files = sorted([os.path.join(img_dir, f) for f in os.listdir(img_dir) if f.endswith('.png')])
dataset = reidDataset(candidates_files, transform=transform)

loader = DataLoader(dataset, batch_size=64, num_workers=4, shuffle=False)


candidate_features = []

print(f"Feature Extracting...")
with torch.no_grad():
    for batch_imgs in loader:
        batch_imgs = batch_imgs.to('cuda')
        features = extractor.model(batch_imgs)
        candidate_features.append(features)

candidate_features = torch.cat(candidate_features, dim=0)
# Out:
# Successfully loaded imagenet pretrained weights from "/home/h8an/.cache/torch/checkpoints/osnet_x1_0_imagenet.pth"
# ** The following layers are discarded due to unmatched keys or layer size: ['classifier.weight', 'classifier.bias']
# Model: osnet_x1_0
# - params: 2,193,616
# - flops: 978,878,352
# Feature Extracting...

# %%
query_image = './reid_data/my_dataset/query/query.png'
query_feature = extractor(query_image)
query = query_feature
candidate = candidate_features
# cosine similarity
sim = F.cosine_similarity(query, candidate)

# %%
import matplotlib.pyplot as plt

top_k = 10
values, indices = torch.topk(sim, k=top_k)

print(f"--- Top {top_k} Similarity Results with Query ---")

plt.figure(figsize=(5, 5)) 


plt.subplot(1,1, 1)
query_raw = plt.imread('./reid_data/my_dataset/query/query.png')
plt.imshow(query_raw)
plt.title("QUERY", color='blue', fontweight='bold')
plt.axis('off')
plt.show()

plt.figure(figsize=(15,5))

for i in range(top_k):
    idx = indices[i].item()
    similarity = values[i].item()
    img_path = candidates_files[idx]
    
    plt.subplot(1, top_k + 1, i + 2) 
    img = plt.imread(img_path)
    plt.imshow(img)

    plt.title(f"Rank {i+1}\n{similarity:.4f}")
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# --- Top 10 Similarity Results with Query ---

# %%
top_k = 10
values, indices = torch.topk(sim, k=top_k)

print(f"--- {top_k} Similarity Results ---")
plt.figure(figsize=(15, 5))

for i in range(top_k):
    idx = indices[i].item()
    similarity = values[i].item()
    img_path = candidates_files[idx]
    
    plt.subplot(1, top_k, i + 1)
    img = plt.imread(img_path)
    plt.imshow(img)
    plt.title(f"Rank {i+1}\nSim: {similarity:.4f}")
    plt.axis('off')
    
    print(f"Rank {i+1}: {img_path} (Similarity: {similarity:.4f})")

plt.show()
# Out:
# --- 10 Similarity Results ---
# Rank 1: ./reid_data/my_dataset/bounding_box_test/frame_1390_ped_1.png (Similarity: 0.8291)
# Rank 2: ./reid_data/my_dataset/bounding_box_test/frame_1380_ped_1.png (Similarity: 0.8177)
# Rank 3: ./reid_data/my_dataset/bounding_box_test/frame_1365_ped_1.png (Similarity: 0.8170)
# Rank 4: ./reid_data/my_dataset/bounding_box_test/frame_1395_ped_0.png (Similarity: 0.7994)
# Rank 5: ./reid_data/my_dataset/bounding_box_test/frame_1355_ped_4.png (Similarity: 0.7904)
# Rank 6: ./reid_data/my_dataset/bounding_box_test/frame_2075_ped_0.png (Similarity: 0.7895)
# Rank 7: ./reid_data/my_dataset/bounding_box_test/frame_1545_ped_2.png (Similarity: 0.7868)
# Rank 8: ./reid_data/my_dataset/bounding_box_test/frame_1555_ped_1.png (Similarity: 0.7836)
# Rank 9: ./reid_data/my_dataset/bounding_box_test/frame_1345_ped_2.png (Similarity: 0.7819)
# Rank 10: ./reid_data/my_dataset/bounding_box_test/frame_295_ped_0.png (Similarity: 0.7782)

# %%
torchreid.models.show_avai_models()
# Out:
# ['resnet18', 'resnet34', 'resnet50', 'resnet101', 'resnet152', 'resnext50_32x4d', 'resnext101_32x8d', 'resnet50_fc512', 'se_resnet50', 'se_resnet50_fc512', 'se_resnet101', 'se_resnext50_32x4d', 'se_resnext101_32x4d', 'densenet121', 'densenet169', 'densenet201', 'densenet161', 'densenet121_fc512', 'inceptionresnetv2', 'inceptionv4', 'xception', 'resnet50_ibn_a', 'resnet50_ibn_b', 'nasnsetmobile', 'mobilenetv2_x1_0', 'mobilenetv2_x1_4', 'shufflenet', 'squeezenet1_0', 'squeezenet1_0_fc512', 'squeezenet1_1', 'shufflenet_v2_x0_5', 'shufflenet_v2_x1_0', 'shufflenet_v2_x1_5', 'shufflenet_v2_x2_0', 'mudeep', 'resnet50mid', 'hacnn', 'pcb_p6', 'pcb_p4', 'mlfn', 'osnet_x1_0', 'osnet_x0_75', 'osnet_x0_5', 'osnet_x0_25', 'osnet_ibn_x1_0', 'osnet_ain_x1_0', 'osnet_ain_x0_75', 'osnet_ain_x0_5', 'osnet_ain_x0_25']

# %%
import sys
print(sys.executable)
# Out:
# /opt/conda/bin/python
